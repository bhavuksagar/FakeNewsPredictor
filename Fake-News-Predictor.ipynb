# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("news.csv")

# %%
data.label[5]
# Out:
# 'FAKE'

# %%
data.describe()
# Out:
#          Unnamed: 0
# count   6335.000000
# mean    5280.415627
# std     3038.503953
# min        2.000000
# 25%     2674.500000
# 50%     5271.000000
# 75%     7901.000000
# max    10557.000000

# %%
x=data.text
y=data.label

# %%
len(y_train)
# Out:
# 4751

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1)

# %%
len(x_train),len(x_test)
# Out:
# (4751, 1584)

# %%
cv=CountVectorizer(stop_words='english',max_features=10000,ngram_range=(1,3))
x_train_cv=cv.fit_transform(x_train)
x_test_cv=cv.transform(x_test)

# %%
cv.get_feature_names()
# Out:
# ['00',
#  '000',
#  '000 000',
#  '000 emails',
#  '000 jobs',
#  '000 people',
#  '000 year',
#  '01',
#  '03',
#  '07',
#  '08',
#  '09',
#  '10',
#  '10 000',
#  '10 2016',
#  '10 brainforce',
#  '10 brainforce 25',
#  '10 days',
#  '10 million',
#  '10 percent',
#  '10 year',
#  '10 years',
#  '100',
#  '100 000',
#  '100 days',
#  '100 million',
#  '100 percent',
#  '1000',
#  '11',
#  '11 16',
#  '11 2001',
#  '11 2016',
#  '11 attacks',
#  '11 days',
#  '11 million',
#  '11 percent',
#  '12',
#  '12 million',
#  '12 percent',
#  '12 year',
#  '120',
#  '13',
#  '13 percent',
#  '130',
#  '14',
#  '14 percent',
#  '140',
#  '14th',
#  '15',
#  '15 000',
#  '15 percent',
#  '15 year',
#  '15 year old',
#  '15 years',
#  '150',
#  '16',
#  '17',
#  '17 percent',
#  '18',
#  '18 months',
#  '18 percent',
#  '19',
#  '19 percent',
#  '1930s',
#  '1945',
#  '1948',
#  '1960',
#  '1960s',
#  '1964',
#  '1967',
#  '1968',
#  '1970',
#  '1970s',
#  '1972',
#  '1973',
#  '1976',
# ...

# %%
cv.vocabulary_
# Out:
# {'donald': 2796,
#  'trump': 9218,
#  'going': 3869,
#  'republican': 7461,
#  'nominee': 5979,
#  'way': 9722,
#  'won': 9869,
#  'happens': 4077,
#  'struck': 8614,
#  'pull': 7076,
#  'mask': 5463,
#  'reveal': 7580,
#  'actually': 391,
#  'impossible': 4440,
#  'mission': 5679,
#  'force': 3611,
#  'agent': 486,
#  'hunt': 4347,
#  'time': 9042,
#  'short': 8162,
#  'want': 9666,
#  'say': 7882,
#  'american': 587,
#  'politics': 6684,
#  'exception': 3232,
#  'polls': 6694,
#  'indiana': 4494,
#  'net': 5902,
#  'bunch': 1311,
#  'delegates': 2446,
#  'set': 8086,
#  'dominate': 2778,
#  'west': 9776,
#  'virginia': 9582,
#  'new': 5916,
#  'jersey': 4796,
#  'road': 7655,
#  'looks': 5279,
#  'likely': 5202,
#  'win': 9822,
#  'california': 1354,
#  'means': 5507,
#  'probably': 6936,
#  'secure': 7973,
#  'majority': 5360,
#  'early': 2899,
#  'june': 4880,
#  'states': 8517,
#  'voted': 9618,
#  'll': 5239,
#  'ballot': 932,
#  'national': 5830,
#  'convention': 2082,
# ...

# %%
clg1=SVC()
clg1.fit(x_train_cv,y_train)
# Out:
# /Users/sahilsagar/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
print("SVM Algorithm")
print("Testing Data Score:",clg1.score(x_test_cv,y_test))
print("Training Data Score:",clg1.score(x_train_cv,y_train))
# Out:
# SVM Algorithm
# Testing Data Score: 0.8566919191919192
# Training Data Score: 0.8665544095979794

# %%
clg2=RandomForestClassifier()
clg2.fit(x_train_cv,y_train)
# Out:
# /Users/sahilsagar/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print("Random Forest Algorithm")
print("Testing Data Score:",clg2.score(x_test_cv,y_test))
print("Training Data Score:",clg2.score(x_train_cv,y_train))
# Out:
# Random Forest Algorithm
# Testing Data Score: 0.8661616161616161
# Training Data Score: 0.9962113239318038

# %%
clg3=MultinomialNB()
clg3.fit(x_train_cv,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print("MultinomialNB Algorithm")
print("Testing Data Score:",clg3.score(x_test_cv,y_test))
print("Training Data Score:",clg3.score(x_train_cv,y_train))
# Out:
# MultinomialNB Algorithm
# Testing Data Score: 0.8977272727272727
# Training Data Score: 0.9101241843822353

# %%
clg4=KNeighborsClassifier(n_neighbors=5)
clg4.fit(x_train_cv,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
print("KNN Algorithm")
print("Testing Data Score:",clg4.score(x_test_cv,y_test))
print("Training Data Score:",clg4.score(x_train_cv,y_train))
# Out:
# KNN Algorithm
# Testing Data Score: 0.7948232323232324
# Training Data Score: 0.8408756051357609
